# %%
import numpy as np
import random

# %%
arquivo = "distancia.csv"
matriz = np.genfromtxt(arquivo, delimiter=',')

# %%
def initialSol(a,b):
    x = list(range(a,b))
    random.shuffle(x)
    return x

# %%
x = list(range(0,250))
custo = []
for i in range(len(x)-1):
    print(f'De {x[i]} para {x[i+1]}')
    custo.append(matriz[x[i]][x[i+1]])
custo.append(matriz[x[len(x)-1]][x[0]])
# Out:
# De 0 para 1
# De 1 para 2
# De 2 para 3
# De 3 para 4
# De 4 para 5
# De 5 para 6
# De 6 para 7
# De 7 para 8
# De 8 para 9
# De 9 para 10
# De 10 para 11
# De 11 para 12
# De 12 para 13
# De 13 para 14
# De 14 para 15
# De 15 para 16
# De 16 para 17
# De 17 para 18
# De 18 para 19
# De 19 para 20
# De 20 para 21
# De 21 para 22
# De 22 para 23
# De 23 para 24
# De 24 para 25
# De 25 para 26
# De 26 para 27
# De 27 para 28
# De 28 para 29
# De 29 para 30
# De 30 para 31
# De 31 para 32
# De 32 para 33
# De 33 para 34
# De 34 para 35
# De 35 para 36
# De 36 para 37
# De 37 para 38
# De 38 para 39
# De 39 para 40
# De 40 para 41
# De 41 para 42
# De 42 para 43
# De 43 para 44
# De 44 para 45
# De 45 para 46
# De 46 para 47
# De 47 para 48
# De 48 para 49
# De 49 para 50
# De 50 para 51
# De 51 para 52
# De 52 para 53
# De 53 para 54
# De 54 para 55
# De 55 para 56
# De 56 para 57
# De 57 para 58
# De 58 para 59
# De 59 para 60
# De 60 para 61
# De 61 para 62
# De 62 para 63
# ...

# %%
sum(custo)
# Out:
# 13375.400000000009

# %%
i = 2
j = 10
print(x[i], x[j])
# Out:
# 2 10

# %%
y = x[:]
y[i], y[j] = y[j], y[i]

# %%
print(x[i], x[j])
# Out:
# 10 2

# %%
from itertools import permutations

# %%
permutations(x,2)
